# %% [markdown]
# # FIR BandPass Filter

# %%
import numpy as np
import scipy.signal as sig
import matplotlib.pyplot as plt

# %%
fs = 8000
N = 100;
fc = np.array([1200, 1800])

# %%
b = sig.firwin(N + 1, fc, fs = fs, window = 'hamming', pass_zero= 'bandpass')

# %%
plt.figure(figsize = (8, 4))
plt.stem(np.arange(len(b)), b)
plt.grid(True)
plt.xlabel('sample')
plt.ylabel('Amplitude')
# Out:
# Text(0, 0.5, 'Amplitude')

# %%
w, h_freq = sig.freqz(b, fs = fs)

# %%
plt.figure(figsize = (9, 3))
plt.plot(w, np.abs(h_freq))
plt.grid(True)
plt.xlabel('frequency(Hz)')
plt.ylabel('Amplitude')
# Out:
# Text(0, 0.5, 'Amplitude')

# %%
plt.figure(figsize = (9, 3))
plt.plot(w, np.unwrap(np.angle(h_freq)))
plt.grid(True)
plt.xlabel('Frequency(Hz)')
plt.ylabel('Amplitude')
# Out:
# Text(0, 0.5, 'Amplitude')

# %%
z, p, k = sig.tf2zpk(b, 1)

# %%
plt.figure(figsize = (9, 4))
plt.scatter(np.real(z), np.imag(z), marker = 'o', edgecolors = 'black')
plt.scatter(np.real(p), np.imag(p), marker = 'x', edgecolors = 'green')
plt.xlabel('real')
plt.ylabel('imaginary')
plt.grid(True)
# Out:
# C:\Users\islam\AppData\Local\Temp\ipykernel_2852\261703582.py:3: UserWarning: You passed a edgecolor/edgecolors ('green') for an unfilled marker ('x').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   plt.scatter(np.real(p), np.imag(p), marker = 'x', edgecolors = 'green')
