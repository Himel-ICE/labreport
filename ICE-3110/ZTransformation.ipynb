# %% [markdown]
# # Ztransforms

# %%
import scipy.signal as sig
from lcapy.discretetime import n
import numpy as np
import matplotlib.pyplot as plt

# %%
x = 1 / 16 ** n
Z = x.ZT()
print(Z)
# Out:
# 16*z/(16*z - 1)

# %%
x = Z.IZT()
print(x)
# Out:
# Piecewise((16**(-n), n >= 0))

# %%
num = [1, 0, 0, 1, 0]
den = [1, 0, 2, 0, 1]
[z, p, k] = sig.tf2zpk(num, den)

# %%
plt.figure(figsize = (10, 4))
plt.scatter(np.real(z), np.imag(z), marker = 'o', edgecolors = 'b')
plt.scatter(np.real(p), np.imag(p), marker = 'x', edgecolors = 'b')
plt.grid(True)
# Out:
# C:\Users\islam\AppData\Local\Temp\ipykernel_1072\1551213402.py:3: UserWarning: You passed a edgecolor/edgecolors ('b') for an unfilled marker ('x').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   plt.scatter(np.real(p), np.imag(p), marker = 'x', edgecolors = 'b')
