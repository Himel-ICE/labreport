# %%
import cv2 
import numpy as np 
import matplotlib.pyplot as plt

# %%
image = cv2.imread("main.png")
mask = cv2.imread("mask.png", cv2.IMREAD_GRAYSCALE)
plt.figure(figsize=(8, 6))
plt.subplot(2, 2, 1)
plt.title("Original Image")
plt.axis("off")
plt.imshow(image)
plt.subplot(2, 2, 2)
plt.title("Mask Image")
plt.axis("off")
plt.imshow(mask, cmap='gray')

# %%
print(image.shape)
print(mask.shape)
# Out:
# (630, 630, 3)
# (630, 630)

# %%
pixel_size = 0.01

# %%
region_of_interest = cv2.bitwise_and(image, image, mask=mask)

# %%
pixel_area = np.sum(mask != 0)
total_pixel = np.sum(mask)
area = pixel_area * pixel_size 
print("Area of the region:", area)  
print(pixel_area)
print(630*630)
print("Total: ", (pixel_area/total_pixel)*100, "% of main image")
# Out:
# Area of the region: 35.51
# 3551
# 396900
# Total:  0.977316137413236 % of main image

# %%
labeled_image = cv2.addWeighted(image, .5, cv2.cvtColor(mask, cv2.COLOR_GRAY2BGR), 1, 0)

# %%
plt.figure(figsize=(6, 6))
plt.subplot(3, 3, 1)
plt.title("Original Image")
plt.axis("off")
plt.imshow(image)
plt.subplot(3, 3, 2)
plt.title("Mask Image")
plt.axis("off")
plt.imshow(mask, cmap='gray')
plt.subplot(3, 3, 3)
plt.title("labeld Image")
plt.axis("off")
plt.imshow(labeled_image)
