# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
fc = 50
fm = 2
fs = 1000
t = 1
duty  = 20
n = np.arange(0, t, 1/fs)

# %%
s = np.sin(2 * np.pi * fc * n)
s[s < 0] = 0

# %%
m = np.sin(2 * np.pi * fm * (n - 1))
plt.figure(figsize=(10, 3))
plt.plot(n, m)

# %%
period_sample = len(n) / fc
period_sample
# Out:
# 20.0

# %%
index = np.arange(0, len(n), int(period_sample))
index
# Out:
# array([  0,  20,  40,  60,  80, 100, 120, 140, 160, 180, 200, 220, 240,
#        260, 280, 300, 320, 340, 360, 380, 400, 420, 440, 460, 480, 500,
#        520, 540, 560, 580, 600, 620, 640, 660, 680, 700, 720, 740, 760,
#        780, 800, 820, 840, 860, 880, 900, 920, 940, 960, 980])

# %%
on_sample = int(np.ceil(period_sample * duty / 100))
on_sample
# Out:
# 4

# %%
pam = np.zeros_like(n)

# %%
carrier_pulse_train = np.where(s > 0.35, 1, 0)

# %%
plt.figure(figsize=(10, 3))
plt.plot(n, carrier_pulse_train[: len(n)])

# %%
for i in range(len(index)):
    pam[index[i] : index[i] + on_samp] = m[index[i]]

# %%
plt.figure(figsize=(10, 3))
plt.plot(n, pam)
plt.grid(True)
plt.ylim([-1.2, 1.2])
# Out:
# (-1.2, 1.2)
