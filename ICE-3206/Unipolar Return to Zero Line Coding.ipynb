# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
N = 10
n = np.random.randint(0, 2, N)
n
# Out:
# array([0, 1, 0, 1, 0, 1, 1, 1, 0, 0])

# %%
t = np.arange(0, N, 0.01)
nn = [1 if bit == 1 else 0 for bit in n]
nn = np.repeat(nn, int(len(t)/N))
#nn

# %%
t = np.arange(0, len(n), 0.01)
print(len(t))
#t
# Out:
# 1000

# %%
y = np.zeros(len(t))
len(y)
# Out:
# 1000

# %%
i = 1
a = 0
b = 0.5

# %%
for j in range(len(t)):
    if t[j] >= a and t[j] <= b:
        y[j] = nn[j]
    elif t[j] > b and t[j] < i:
        y[j] = 0
    else:
        i = i + 1
        a = a + 1
        b = b + 1

# %%
print(n)
# Out:
# [0 1 0 1 0 1 1 1 0 0]

# %%
plt.figure(figsize=(16, 6))
plt.plot(t, y, linewidth=2)
plt.axis([0, N, -1.5, 1.5])
plt.grid(True)
plt.title('Unipolar NZR Signaling')
# Out:
# Text(0.5, 1.0, 'Unipolar NZR Signaling')
